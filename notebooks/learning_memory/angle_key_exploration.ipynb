# %% [markdown]
# In this notebook, we explore how the learning and memory can be driven by curiosity, confidence level and timeloss memory. Everytime a source is reached, a new source is chosen as the next target based on a table associated to the fly; in this table, the confidence level of how well the fly knows all the sources is stored. This confidence level decreases with time; everytime a source is reached, this value decreases for each sources; if its negative, it is set equal to zero.
#
# After this first explaration, we want the fly to be able to walk to the different sources based on its internal state; the mating state and the food stock levels (AAs level) will guide its exploration.

# %%
import numpy as np
import matplotlib.pyplot as plt
import logging
import os
from pathlib import Path
from tqdm import trange
from flygym.mujoco import Parameters
from flygym.mujoco.examples.turning_controller import HybridTurningNMF
from flygym.mujoco.arena import OdorArena

# Odor source: array of shape (num_odor_sources, 3) - xyz coords of odor sources
odor_source = np.array(
    [[24, 0, 1.5], [8, -4, 1.5], [16, 4, 1.5], [12, -8, 1.5], [20, 3, 1.5]]
)

# Peak intensities: array of shape (num_odor_sources, odor_dimesions)
peak_intensity = np.array([[1, 3], [2, 6], [3, 7], [4, 1], [5, 3]])

# Marker colors: array of shape (num_odor_sources, 4) - RGBA values for each marker,
# normalized to [0, 1]
marker_colors = [
    [255, 127, 14],
    [31, 119, 180],
    [255, 192, 203],
    [255, 0, 0],
    [0, 255, 0],
]
marker_colors = np.array([[*np.array(color) / 255, 1] for color in marker_colors])

odor_dimesions = len(peak_intensity[0])

odor_valence = [10, 15, 20, 17, 6]

logging.basicConfig(level=logging.INFO)

# %%
# Set up the arena
arena = OdorArena(
    odor_source=odor_source,
    size=(50, 50),
    peak_intensity=peak_intensity,
    odor_valence=odor_valence,
    diffuse_func=lambda x: x**-2,
    marker_size=0.3,
    marker_colors=marker_colors,
    key_angle= True  # we add this boolean so that we compute the key for the valence dictionary by using the angle formed in the complex plane
)

# Add the NeuroMechFLy

contact_sensor_placements = [
    f"{leg}{segment}"
    for leg in ["LF", "LM", "LH", "RF", "RM", "RH"]
    for segment in ["Tibia", "Tarsus1", "Tarsus2", "Tarsus3", "Tarsus4", "Tarsus5"]
]
sim_params = Parameters(
    timestep=1e-4,
    render_mode="saved",
    render_playspeed=0.5,
    render_window_size=(800, 608),
    enable_olfaction=True,
    enable_adhesion=True,
    draw_adhesion=False,
    render_camera="birdeye_cam",
)
sim = HybridTurningNMF(
    sim_params=sim_params,
    arena=arena,
    spawn_pos=(0, 0, 0.2),
    contact_sensor_placements=contact_sensor_placements,
    simulation_time=140,
)
# odor_score_reach_addition=2,
# odor_score_time_loss=1
for i in range(1):
    sim.step(np.zeros(2))
    sim.render()
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.imshow(sim._frames[-1])
ax.axis("off")
# Out:
# (-0.5, 799.5, 607.5, -0.5)

# %%
# Let's start the simulation
decision_interval = 0.01
run_time = 70 #sim.simulation_time / 2
num_decision_steps = int(run_time / decision_interval)
logging.info("Number of decision steps: ", num_decision_steps)
physics_steps_per_decision_step = int(decision_interval / sim_params.timestep)
logging.info("Physics steps per decision step: ", physics_steps_per_decision_step)

obs_hist = []
odor_history = []
obs, _ = sim.reset()

peak_intensity = np.empty(np.shape(arena.peak_odor_intensity))
for el in range(len(arena.peak_odor_intensity)):
    peak_intensity[el] = [1, 0]

# Let's choose the source towards which the fly will walk
source = sim.choose_odor_exploration()
prev_reward = None
logging.info("Going to the source ", source + 1)
print(source)

# Let's start the exploration
for i in trange(num_decision_steps):
    # compute the control signal to go towards the chosen source
    control_signal = arena.generate_specific_turning_control(source, sim, peak_intensity)
    for _ in range(physics_steps_per_decision_step):
        obs, reward, terminated, truncated, _ = sim.step(control_signal, False, True)
        rendered_img = sim.render()
        if rendered_img is not None:
            # record odor intensity too for video
            odor_history.append(obs["odor_intensity"])
        obs_hist.append(obs)

        if reward != None:
            # let's check if the fly has actually reached a new source
            if prev_reward != reward:
                # if it has, the sim.odor_scores is updated and a new source to be reached is computed
                sim.update_odor_scores(source)
                sim.update_odor_scores_key(source)
                source = sim.choose_odor_exploration()
                logging.info("new source", source + 1)
                logging.info(sim.odor_scores)
                prev_reward = reward
        if terminated:
            logging.info("Out of time")
            logging.info("Elapsed time in the simulation", sim.curr_time)
            break
        if truncated:
            logging.info("No food source was reached, simulation is truncated")
            logging.info("Elapsed time in the simulation", sim.curr_time)
            break
# Out:
# 3
#   0%|          | 0/7000 [00:00<?, ?it/s]
# 100%|██████████| 7000/7000 [34:11<00:00,  3.41it/s]

# %%
# Let's check the confidence level for the fly's memory related to the different sources
print(sim.odor_scores)
# Let's check the fly's memory
print(sim.fly_valence_dictionary)
print(arena.valence_dictionary)

print(sim.key_odor_scores)
# Out:
# [15. 45. 30. 30. 45.]
# {1.3258176636680326: 17, 1.0303768265243125: 6, 0.32175055439664224: 15, 0.4048917862850834: 20}
# {0.32175055439664224: 15, 0.4048917862850834: 20, 1.3258176636680326: 17, 1.0303768265243125: 6}
# {0.32175055439664224: 51.0, 0.4048917862850834: 22.0, 1.3258176636680326: 19.0, 1.0303768265243125: 35.0}

# %%
# Choose a name to save both the video and the trajectory
name = "angle_counting_based_simulation_internal_rdm"
path = Path(f"/home/nmf-learning/flygym-scratch/outputs/plots/{name}")
os.mkdir(path)

# %%
# Plot the trajectory
fly_pos_hist = np.array([obs["fly"][0, :2] for obs in obs_hist])
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.scatter(
    [odor_source[0, 0]],
    [odor_source[0, 1]],
    marker="o",
    color="tab:orange",
    s=50,
    label="Source 1",
)
ax.scatter(
    [odor_source[1, 0]],
    [odor_source[1, 1]],
    marker="o",
    color="tab:blue",
    s=50,
    label="Source 2",
)
ax.scatter(
    [odor_source[2, 0]],
    [odor_source[2, 1]],
    marker="o",
    color="tab:pink",
    s=50,
    label="Source 3",
)
ax.scatter(
    [odor_source[3, 0]],
    [odor_source[3, 1]],
    marker="o",
    color="tab:red",
    s=50,
    label="Source 4",
)
ax.scatter(
    [odor_source[4, 0]],
    [odor_source[4, 1]],
    marker="o",
    color="tab:green",
    s=50,
    label="Source 5",
)
ax.plot(fly_pos_hist[:, 0], fly_pos_hist[:, 1], color="k", label="Fly trajectory discovery")
ax.set_aspect("equal")
ax.set_xlim(-1, 40)
ax.set_ylim(-10, 10)
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.legend(ncols=3, loc="lower center", bbox_to_anchor=(0.5, -0.6))
fig.savefig(
    f"/home/nmf-learning/flygym-scratch/outputs/plots/{name}/odor_taxis_trajectory.png"
)

# %%
# save the video
sim.save_video(
    f"/home/nmf-learning/flygym-scratch/outputs/plots/{name}/odor_taxis_video_exploration.mp4"
)

# %%
# Let's start the simulation
decision_interval = 0.01
run_time = 70 #sim.simulation_time / 2
num_decision_steps = int(run_time / decision_interval)
logging.info("Number of decision steps: ", num_decision_steps)
physics_steps_per_decision_step = int(decision_interval / sim_params.timestep)
logging.info("Physics steps per decision step: ", physics_steps_per_decision_step)

obs_hist = []
odor_history = []
obs, _ = sim.reset()

# Let's choose the source towards which the fly will walk
source = sim.choose_odor_exploration()
prev_reward = None
logging.info("Going to the source ", source + 1)
print(source)

# Let's start the exploration
for i in trange(num_decision_steps):
    # compute the control signal to go towards the chosen source
    control_signal = arena.generate_specific_turning_control(source, sim)
    for _ in range(physics_steps_per_decision_step):
        obs, reward, terminated, truncated, _ = sim.step(control_signal, False, True)
        rendered_img = sim.render()
        if rendered_img is not None:
            # record odor intensity too for video
            odor_history.append(obs["odor_intensity"])
        obs_hist.append(obs)

        if reward != None:
            # let's check if the fly has actually reached a new source
            if prev_reward != reward:
                # if it has, the sim.odor_scores is updated and a new source to be reached is computed
                sim.update_odor_scores(source)
                sim.update_odor_scores_key(source)
                source = sim.choose_odor_exploration()
                logging.info("new source", source + 1)
                logging.info(sim.odor_scores)
                prev_reward = reward
        if terminated:
            logging.info("Out of time")
            logging.info("Elapsed time in the simulation", sim.curr_time)
            break
        if truncated:
            logging.info("No food source was reached, simulation is truncated")
            logging.info("Elapsed time in the simulation", sim.curr_time)
            break
# Out:
# 2
#   0%|          | 0/7000 [00:00<?, ?it/s]
#   4%|▍         | 264/7000 [01:31<50:05,  2.24it/s]
# 0
#   5%|▌         | 356/7000 [02:02<36:53,  3.00it/s]
# 4
#  45%|████▍     | 3146/7000 [15:55<19:26,  3.31it/s]
# 1
#  52%|█████▏    | 3644/7000 [18:33<18:08,  3.08it/s]
# 3
#  60%|█████▉    | 4199/7000 [21:23<14:15,  3.27it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb Cell 9 line 2
#      <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a> control_signal = arena.generate_specific_turning_control(source, sim)
#      <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a> for _ in range(physics_steps_per_decision_step):
# ---> <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=23'>24</a>     obs, reward, terminated, truncated, _ = sim.step(control_signal, False, True)
#      <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a>     rendered_img = sim.render()
#      <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>     if rendered_img is not None:
#      <a href='vscode-notebook-cell://ssh-remote%2B128.178.197.47/home/nmf-learning/flygym-scratch/notebooks/learning_memory/angle_key_exploration.ipynb#X11sdnNjb2RlLXJlbW90ZQ%3D%3D?line=26'>27</a>         # record odor intensity too for video
#
# File ~/flygym-scratch/flygym/mujoco/examples/turning_controller.py:256, in HybridTurningNMF.step(self, action, truncation, angle_key)
#     250     adhesion_onoff.append(my_adhesion_onoff)
#     252 action = {
#     253     "joints": np.array(np.concatenate(joints_angles)),
#     254     "adhesion": np.array(adhesion_onoff).astype(int),
#     255 }
# --> 256 return super().step(action, truncation, angle_key)
#
# File ~/flygym-scratch/flygym/mujoco/core.py:1364, in NeuroMechFly.step(self, action, truncation, angle_key)
#    1362 self.curr_time += self.timestep
#    1363 self.elapsed_time += self.timestep
# -> 1364 observation = self.get_observation()
#    1365 reward = self.get_reward(observation, angle_key)
#    1366 terminated = self.is_terminated()
#
# File ~/flygym-scratch/flygym/mujoco/core.py:1788, in NeuroMechFly.get_observation(self)
#    1786         contactid_normal[contact_sensor_id] = [contact.frame[:3]]
#    1787     self._active_adhesion[id] = True
# -> 1788 id = np.where(self._adhesion_actuator_geomid == contact.geom2)
#    1789 if len(id[0]) > 0 and contact.exclude == 0:
#    1790     contact_sensor_id = self._adhesion_bodies_with_contact_sensors[id][
#    1791         0
#    1792     ]
#
# File ~/miniconda3/envs/nmf/lib/python3.11/site-packages/numpy/core/multiarray.py:434, in where(condition, x, y)
#     344     """
#     345     inner(a, b, /)
#     346
#    (...)
#     429
#     430     """
#     431     return (a, b)
# --> 434 @array_function_from_c_func_and_dispatcher(_multiarray_umath.where)
#     435 def where(condition, x=None, y=None):
#     436     """
#     437     where(condition, [x, y], /)
#     438
#    (...)
#     504            [ 0,  3, -1]])
#     505     """
#     506     return (condition, x, y)
#
# KeyboardInterrupt:

# %%
name = "angle_counting_based_simulation_internal_rdm"

# %%
# Let's check the confidence level for the fly's memory related to the different sources
print(sim.odor_scores)
# Let's check the fly's memory
print(sim.fly_valence_dictionary)
print(arena.valence_dictionary)

print(sim.key_odor_scores)
# Out:
# [15. 15. 15.  0. 15.]
# {0.4048917862850834: 20, 1.0303768265243125: 6, 0.32175055439664224: 15}
# {0.32175055439664224: 15, 0.4048917862850834: 20, 1.3258176636680326: 17, 1.0303768265243125: 6}
# {0.32175055439664224: 27.0, 0.4048917862850834: 11.0, 1.3258176636680326: 0, 1.0303768265243125: 13.0}

# %%
# Plot the trajectory
fly_pos_hist = np.array([obs["fly"][0, :2] for obs in obs_hist])
fig, ax = plt.subplots(1, 1, figsize=(5, 4), tight_layout=True)
ax.scatter(
    [odor_source[0, 0]],
    [odor_source[0, 1]],
    marker="o",
    color="tab:orange",
    s=50,
    label="Source 1",
)
ax.scatter(
    [odor_source[1, 0]],
    [odor_source[1, 1]],
    marker="o",
    color="tab:blue",
    s=50,
    label="Source 2",
)
ax.scatter(
    [odor_source[2, 0]],
    [odor_source[2, 1]],
    marker="o",
    color="tab:pink",
    s=50,
    label="Source 3",
)
ax.scatter(
    [odor_source[3, 0]],
    [odor_source[3, 1]],
    marker="o",
    color="tab:red",
    s=50,
    label="Source 4",
)
ax.scatter(
    [odor_source[4, 0]],
    [odor_source[4, 1]],
    marker="o",
    color="tab:green",
    s=50,
    label="Source 5",
)
ax.plot(fly_pos_hist[:, 0], fly_pos_hist[:, 1], color="k", label="Fly trajectory discovery")
ax.set_aspect("equal")
ax.set_xlim(-1, 40)
ax.set_ylim(-10, 10)
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.legend(ncols=3, loc="lower center", bbox_to_anchor=(0.5, -0.6))
fig.savefig(
    f"/home/nmf-learning/flygym-scratch/outputs/plots/{name}/respawn_odor_taxis_trajectory.png"
)

# %%
# save the video
sim.save_video(
    f"/home/nmf-learning/flygym-scratch/outputs/plots/{name}/respawn_odor_taxis_video_exploration.mp4"
)
